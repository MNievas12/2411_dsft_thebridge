# %% [markdown]
# # Regresion Basica: Predecir eficiencia de gasolina

# %% [markdown]
# Este libro usa el set de datos clasico [Auto MPG](https://archive.ics.uci.edu/ml/datasets/auto+mpg) y construye un modelo para predecir el consumo de vehiculos de 1970 y 1980. Para hacer esto proveeremos el modelo con una descripcion de muchos automoviles de ese periodo. Esta descripcion incluye atributos como: Cilindros, desplazamiento, potencia y peso.
#
# El objetivo de este ejercicio es predecir el target miles per galon (MPG), que vendría a representar las millas por galón de combustible.
#
# Este ejemplo usa el API `tf.keras` , revise [Esta Guia](https://www.tensorflow.org/guide/keras) para obtener mas detalles.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow import keras
# Out:
# WARNING:tensorflow:From c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## El set de Datos de MPG
#
# El set de datos esta disponible de el siguiente repositorio [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/).

# %% [markdown]
# ### Obtenga los datos
# Primero descargue el set de datos.
# keras.utils.get_file("auto-mpg.data", "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")

# %%
dataset = keras.utils.get_file("auto-mpg.data", "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")
dataset
# Out:
# 'C:\\Users\\Miguel Angel\\.keras\\datasets\\auto-mpg.data'

# %% [markdown]
# Importelo usando pandas.

# %%
column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model_year', 'Origin', 'Car_name']

# %%
df = pd.read_csv(dataset, names=column_names, delim_whitespace=True)
df
# Out:
#       MPG  Cylinders  Displacement Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      Model_year  Origin                   Car_name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ### Limpia los datos
#
# Trata los missings y variables categóricas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           398 non-null    float64
#  1   Cylinders     398 non-null    int64
#  2   Displacement  398 non-null    float64
#  3   Horsepower    398 non-null    object
#  4   Weight        398 non-null    float64
#  5   Acceleration  398 non-null    float64
#  6   Model_year    398 non-null    int64
#  7   Origin        398 non-null    int64
#  8   Car_name      398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               MPG   Cylinders  Displacement       Weight  Acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        Model_year      Origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df['Horsepower'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df['Horsepower'].astype(float)
#
# File c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '?'

# %%
df[df['Horsepower']=='?']
# Out:
#       MPG  Cylinders  Displacement Horsepower  Weight  Acceleration  \
# 32   25.0          4          98.0          ?  2046.0          19.0
# 126  21.0          6         200.0          ?  2875.0          17.0
# 330  40.9          4          85.0          ?  1835.0          17.3
# 336  23.6          4         140.0          ?  2905.0          14.3
# 354  34.5          4         100.0          ?  2320.0          15.8
# 374  23.0          4         151.0          ?  3035.0          20.5
#
#      Model_year  Origin              Car_name
# 32           71       1            ford pinto
# 126          74       1         ford maverick
# 330          80       2  renault lecar deluxe
# 336          80       1    ford mustang cobra
# 354          81       2           renault 18i
# 374          82       1        amc concord dl

# %%
df['Horsepower'] = np.where(df['Horsepower']=="?", np.nan, df['Horsepower'])
df['Horsepower'] = df['Horsepower'].astype(float)
df.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model_year      Origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.175000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
df['Horsepower'].fillna(df['Horsepower'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           398 non-null    float64
#  1   Cylinders     398 non-null    int64
#  2   Displacement  398 non-null    float64
#  3   Horsepower    398 non-null    float64
#  4   Weight        398 non-null    float64
#  5   Acceleration  398 non-null    float64
#  6   Model_year    398 non-null    int64
#  7   Origin        398 non-null    int64
#  8   Car_name      398 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB

# %%
df['Origin'].value_counts()
# Out:
# 1    249
# 3     79
# 2     70
# Name: Origin, dtype: int64

# %%
df[df['Origin'] == 3]
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 14   24.0          4         113.0        95.0  2372.0          15.0
# 18   27.0          4          97.0        88.0  2130.0          14.5
# 29   27.0          4          97.0        88.0  2130.0          14.5
# 31   25.0          4         113.0        95.0  2228.0          14.0
# 53   31.0          4          71.0        65.0  1773.0          19.0
# ..    ...        ...           ...         ...     ...           ...
# 382  34.0          4         108.0        70.0  2245.0          16.9
# 383  38.0          4          91.0        67.0  1965.0          15.0
# 384  32.0          4          91.0        67.0  1965.0          15.7
# 385  38.0          4          91.0        67.0  1995.0          16.2
# 390  32.0          4         144.0        96.0  2665.0          13.9
#
#      Model_year  Origin               Car_name
# 14           70       3  toyota corona mark ii
# 18           70       3           datsun pl510
# 29           71       3           datsun pl510
# 31           71       3          toyota corona
# 53           71       3    toyota corolla 1200
# ..          ...     ...                    ...
# 382          82       3         toyota corolla
# 383          82       3            honda civic
# 384          82       3     honda civic (auto)
# 385          82       3          datsun 310 gx
# 390          82       3       toyota celica gt
#
# [79 rows x 9 columns]

# %%
df.groupby('Origin')['MPG'].mean()
# Out:
# Origin
# 1    20.083534
# 2    27.891429
# 3    30.450633
# Name: MPG, dtype: float64

# %%
pd.get_dummies(df['Origin'])
# Out:
#      1  2  3
# 0    1  0  0
# 1    1  0  0
# 2    1  0  0
# 3    1  0  0
# 4    1  0  0
# ..  .. .. ..
# 393  1  0  0
# 394  0  1  0
# 395  1  0  0
# 396  1  0  0
# 397  1  0  0
#
# [398 rows x 3 columns]

# %%
marcas = df['Car_name'].str.split(expand=True, n=1)[0]
marcas
# Out:
# 0      chevrolet
# 1          buick
# 2       plymouth
# 3            amc
# 4           ford
#          ...
# 393         ford
# 394           vw
# 395        dodge
# 396         ford
# 397        chevy
# Name: 0, Length: 398, dtype: object

# %%
marcas.value_counts()
# Out:
# ford             51
# chevrolet        43
# plymouth         31
# amc              28
# dodge            28
# toyota           25
# datsun           23
# buick            17
# pontiac          16
# volkswagen       15
# honda            13
# mercury          11
# mazda            10
# oldsmobile       10
# fiat              8
# peugeot           8
# audi              7
# chrysler          6
# vw                6
# volvo             6
# renault           5
# saab              4
# subaru            4
# opel              4
# chevy             3
# bmw               2
# cadillac          2
# maxda             2
# mercedes-benz     2
# triumph           1
# vokswagen         1
# mercedes          1
# hi                1
# capri             1
# chevroelt         1
# toyouta           1
# nissan            1
# Name: 0, dtype: int64

# %%
df['Marca'] = marcas.copy()
df.groupby("Marca")['MPG'].agg(['mean', 'count']).sort_values('mean', ascending=False)
# Out:
#                     mean  count
# Marca
# vw             39.016667      6
# nissan         36.000000      1
# triumph        35.000000      1
# honda          33.761538     13
# renault        32.880000      5
# datsun         31.113043     23
# mazda          30.860000     10
# subaru         30.525000      4
# vokswagen      29.800000      1
# volkswagen     29.106667     15
# fiat           28.912500      8
# toyota         28.372000     25
# audi           26.714286      7
# maxda          26.050000      2
# opel           25.750000      4
# mercedes       25.400000      1
# capri          25.000000      1
# saab           23.900000      4
# bmw            23.750000      2
# peugeot        23.687500      8
# mercedes-benz  23.250000      2
# toyouta        23.000000      1
# dodge          22.060714     28
# plymouth       21.703226     31
# volvo          21.116667      6
# oldsmobile     21.100000     10
# chevrolet      20.472093     43
# pontiac        20.012500     16
# cadillac       19.750000      2
# ford           19.694118     51
# buick          19.182353     17
# mercury        19.118182     11
# amc            18.246429     28
# chevy          18.000000      3
# chrysler       17.266667      6
# chevroelt      16.000000      1
# hi              9.000000      1

# %% [markdown]
# ### Divide los datos en train y test
#
# Ahora divida el set de datos en un set de entrenamiento y otro de pruebas. 80% para entrenamiento
#
# Usaremos el set de pruebas en la evaluacion final de nuestro modelo.
#
# NOTA: El resultado tienen que ser dos datasets

# %%
df.drop(columns=["Car_name", "Marca"], inplace=True)

# %%
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model_year  Origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
train = df.sample(frac=0.8, random_state=42)
test = df.drop(train.index)

# %%
print(train.shape)
print(test.shape)
# Out:
# (318, 8)
# (80, 8)

# %% [markdown]
# ### Inspecciona los datos
#
# Revise rapidamente la distribucion conjunta del dataset de entrenamiento mediante un grid de gráficos

# %%
sns.pairplot(df)

# %% [markdown]
# Tambien revise las estadisticas generales:

# %%
df.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.199187   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   76.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   95.000000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model_year      Origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.175000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
sns.heatmap(df.corr(), annot=True, vmin=-1, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# ### Separa las features del target
#
# Separe el target de las features.

# %%
X_train = train.drop(columns="MPG")
X_test = test.drop(columns="MPG")
y_train = train['MPG']
y_test = test['MPG']

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (318, 7)
# (80, 7)
# (318,)
# (80,)

# %% [markdown]
# ### Estandariza los datos

# %% [markdown]
# Es una buena práctica estandarizar funciones que utilizan diferentes escalas y rangos. Aunque el modelo podría converger sin estandarizar, dificulta el entrenamiento y hace que el modelo resultante dependa de la elección de las unidades utilizadas en la entrada.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scal = scaler.fit_transform(X_train)
X_test_scal = scaler.transform(X_test)

# %% [markdown]
# Estos datos estandarizados es lo que usaremos para entrenar el modelo.

# %% [markdown]
# ## El modelo

# %% [markdown]
# ### Construye el modelo
#
# Construyamos nuestro modelo. Aquí, utilizaremos un modelo `secuencial` con dos capas ocultas densamente conectadas y una capa de salida que devuelve un único valor continuo.
#
# Por tanto, tendrá tres capas. Una de entrada con activación relu. Otra hidden layer con activación relu y la de salida de regresión, que se compondrá de una única neurona. Pon las neuronas que consideres para las dos primeras capas.
#
# Para el compile utiliza un loss='mse'.
#
# optimizer = `tf.keras.optimizers.RMSprop(0.001)`
#
# Y en metrics añade en una lista el `mae` y `mse`.

# %%
X_train.shape
# Out:
# (318, 7)

# %%
model = keras.Sequential([
    keras.layers.Dense(64, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(16),
    keras.layers.Dense(1)
])

model.compile(
    loss = "mse",
    optimizer = keras.optimizers.RMSprop(0.001),
    metrics = ['mae']
)

# %% [markdown]
# ### Inspeccione el modelo
#
# Use el método `.summary` para imprimir una descripción simple del modelo

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 64)                512
#
#  dense_19 (Dense)            (None, 16)                1040
#
#  dense_20 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 1569 (6.13 KB)
# Trainable params: 1569 (6.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
7 * 64 + 64
# Out:
# 512

# %%
64 * 16 + 16
# Out:
# 1040

# %% [markdown]
# ### Entrenar el modelo
#
# Entrene el modelo para 1000 epochs y guarda los resultados del entrenamiento en una variable llamada `history`.
# Emplea en el entrenamiento un 20% de los datos para validación, mediante el argumento `validation_split`.
#
# NOTA: recuerda usar los datos normalizados.

# %%
X_train_scal.shape[0]*0.8/32
# Out:
# 7.95

# %%
early_stopping = keras.callbacks.EarlyStopping(patience=10)

# %%
history = model.fit(
    X_train_scal,
    y_train,
    batch_size=32,
    epochs=1000,
    validation_split=0.2,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/1000
# WARNING:tensorflow:From c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 8/8 [==============================] - 2s 37ms/step - loss: 588.5928 - mae: 23.0051 - val_loss: 502.8377 - val_mae: 20.8754
# Epoch 2/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 543.1916 - mae: 22.0069 - val_loss: 466.5813 - val_mae: 19.9812
# Epoch 3/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 501.9109 - mae: 21.0628 - val_loss: 429.4550 - val_mae: 19.0376
# Epoch 4/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 457.9301 - mae: 20.0295 - val_loss: 389.6104 - val_mae: 17.9847
# Epoch 5/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 411.8902 - mae: 18.8720 - val_loss: 348.7571 - val_mae: 16.8252
# Epoch 6/1000
# 8/8 [==============================] - 0s 15ms/step - loss: 363.4594 - mae: 17.6068 - val_loss: 306.4150 - val_mae: 15.5465
# Epoch 7/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 313.1904 - mae: 16.1968 - val_loss: 263.0787 - val_mae: 14.2574
# Epoch 8/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 262.3812 - mae: 14.7013 - val_loss: 220.4200 - val_mae: 12.9771
# Epoch 9/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 213.8917 - mae: 13.2125 - val_loss: 180.4463 - val_mae: 11.6425
# Epoch 10/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 169.5100 - mae: 11.6897 - val_loss: 144.0611 - val_mae: 10.3049
# Epoch 11/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 130.6157 - mae: 10.1984 - val_loss: 112.6550 - val_mae: 9.0048
# Epoch 12/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 98.9467 - mae: 8.6851 - val_loss: 86.7709 - val_mae: 7.8302
# Epoch 13/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 75.2056 - mae: 7.4040 - val_loss: 66.7885 - val_mae: 6.7177
# Epoch 14/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 58.9387 - mae: 6.3611 - val_loss: 52.6828 - val_mae: 5.8627
# Epoch 15/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 48.8813 - mae: 5.7168 - val_loss: 43.3320 - val_mae: 5.3050
# Epoch 16/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 42.5042 - mae: 5.3375 - val_loss: 37.6126 - val_mae: 4.9357
# Epoch 17/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 37.8359 - mae: 5.0047 - val_loss: 32.8185 - val_mae: 4.5623
# Epoch 18/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 33.8500 - mae: 4.6707 - val_loss: 30.1756 - val_mae: 4.3733
# Epoch 19/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 30.3514 - mae: 4.3818 - val_loss: 26.5660 - val_mae: 4.0237
# Epoch 20/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 27.0996 - mae: 4.1056 - val_loss: 25.3081 - val_mae: 3.9190
# Epoch 21/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 24.3681 - mae: 3.8662 - val_loss: 22.4477 - val_mae: 3.6619
# Epoch 22/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 21.9342 - mae: 3.6790 - val_loss: 20.4963 - val_mae: 3.4698
# Epoch 23/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 19.7823 - mae: 3.4394 - val_loss: 18.8669 - val_mae: 3.3047
# Epoch 24/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 18.1224 - mae: 3.2797 - val_loss: 17.6593 - val_mae: 3.1686
# Epoch 25/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 16.5326 - mae: 3.1146 - val_loss: 16.6050 - val_mae: 3.0639
# Epoch 26/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 15.1686 - mae: 2.9861 - val_loss: 16.6304 - val_mae: 3.0346
# Epoch 27/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 14.1183 - mae: 2.8643 - val_loss: 14.8659 - val_mae: 2.8561
# Epoch 28/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 13.1178 - mae: 2.7308 - val_loss: 14.7074 - val_mae: 2.8193
# Epoch 29/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 12.2931 - mae: 2.6392 - val_loss: 14.5800 - val_mae: 2.7886
# Epoch 30/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 11.4922 - mae: 2.5249 - val_loss: 13.0956 - val_mae: 2.6097
# Epoch 31/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 11.3440 - mae: 2.5076 - val_loss: 13.2146 - val_mae: 2.5722
# Epoch 32/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 10.7461 - mae: 2.4224 - val_loss: 12.8372 - val_mae: 2.5071
# Epoch 33/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 10.2871 - mae: 2.3390 - val_loss: 12.7407 - val_mae: 2.4889
# Epoch 34/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 10.0103 - mae: 2.3040 - val_loss: 13.4760 - val_mae: 2.5280
# Epoch 35/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 9.8006 - mae: 2.2892 - val_loss: 12.6863 - val_mae: 2.4497
# Epoch 36/1000
# 8/8 [==============================] - 0s 12ms/step - loss: 9.4618 - mae: 2.2222 - val_loss: 12.8254 - val_mae: 2.4503
# Epoch 37/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 9.2490 - mae: 2.2024 - val_loss: 11.9337 - val_mae: 2.3813
# Epoch 38/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 9.0077 - mae: 2.1611 - val_loss: 11.8840 - val_mae: 2.3741
# Epoch 39/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 8.8900 - mae: 2.1462 - val_loss: 11.7075 - val_mae: 2.3463
# Epoch 40/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 8.6176 - mae: 2.1315 - val_loss: 11.5667 - val_mae: 2.3485
# Epoch 41/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 8.4710 - mae: 2.1092 - val_loss: 12.5140 - val_mae: 2.3798
# Epoch 42/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 8.3089 - mae: 2.0997 - val_loss: 11.6888 - val_mae: 2.3204
# Epoch 43/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 8.1783 - mae: 2.0568 - val_loss: 11.9981 - val_mae: 2.3318
# Epoch 44/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 8.1795 - mae: 2.0569 - val_loss: 11.9381 - val_mae: 2.3138
# Epoch 45/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.9578 - mae: 2.0210 - val_loss: 11.1107 - val_mae: 2.2607
# Epoch 46/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.9449 - mae: 2.0409 - val_loss: 11.2501 - val_mae: 2.2539
# Epoch 47/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 7.7377 - mae: 2.0086 - val_loss: 11.2458 - val_mae: 2.2460
# Epoch 48/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 7.8061 - mae: 1.9915 - val_loss: 11.7736 - val_mae: 2.2843
# Epoch 49/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 7.7214 - mae: 1.9894 - val_loss: 11.2561 - val_mae: 2.2320
# Epoch 50/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 7.4460 - mae: 1.9625 - val_loss: 11.1114 - val_mae: 2.2161
# Epoch 51/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 7.4718 - mae: 1.9581 - val_loss: 10.9806 - val_mae: 2.2041
# Epoch 52/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.4302 - mae: 1.9431 - val_loss: 11.0502 - val_mae: 2.1984
# Epoch 53/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.3317 - mae: 1.9506 - val_loss: 10.2689 - val_mae: 2.1730
# Epoch 54/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.3189 - mae: 1.9385 - val_loss: 11.0941 - val_mae: 2.1923
# Epoch 55/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 7.1539 - mae: 1.9140 - val_loss: 10.9846 - val_mae: 2.1780
# Epoch 56/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.1384 - mae: 1.9301 - val_loss: 10.6693 - val_mae: 2.1664
# Epoch 57/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.1418 - mae: 1.9286 - val_loss: 10.6767 - val_mae: 2.1566
# Epoch 58/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 7.0214 - mae: 1.8968 - val_loss: 11.2539 - val_mae: 2.1988
# Epoch 59/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.0005 - mae: 1.8975 - val_loss: 10.6128 - val_mae: 2.1536
# Epoch 60/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.9094 - mae: 1.8831 - val_loss: 10.1389 - val_mae: 2.1288
# Epoch 61/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.0777 - mae: 1.9081 - val_loss: 10.1381 - val_mae: 2.1309
# Epoch 62/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 6.8251 - mae: 1.8689 - val_loss: 10.8080 - val_mae: 2.1389
# Epoch 63/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 6.9179 - mae: 1.9010 - val_loss: 10.2962 - val_mae: 2.1252
# Epoch 64/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.8319 - mae: 1.8833 - val_loss: 10.4328 - val_mae: 2.1227
# Epoch 65/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.6834 - mae: 1.8735 - val_loss: 10.6960 - val_mae: 2.1317
# Epoch 66/1000
# 8/8 [==============================] - 0s 7ms/step - loss:
#   4.562265396118164,
#   4.373349666595459,
#   4.023650169372559,
#   3.9189510345458984,
#   3.661930561065674,
#   3.469773530960083,
#   3.3046703338623047,
#   3.168649673461914,
#   3.0638766288757324,
#   3.034644842147827,
#   2.856074571609497,
#   2.8192543983459473,
#   2.7885684967041016,
#   2.609710693359375,
#   2.5722155570983887,
#   2.50710391998291,
#   2.488938570022583,
#   2.528038501739502,
#   2.4497017860412598,
#   2.4503495693206787,
#   2.381251335144043,
#   2.3741414546966553,
#   2.346284866333008,
#   2.3484883308410645,
#   2.379849433898926,
#   2.320375680923462,
#   2.331796884536743,
#   2.313750743865967,
#   2.2607250213623047,
#   2.2538557052612305,
#   2.245992660522461,
#   2.284334659576416,
#   2.2319765090942383,
#   2.216094970703125,
#   2.2041380405426025,
#   2.1984314918518066,
#   2.172980308532715,
#   2.192304849624634,
#   2.1780285835266113,
#   2.1663527488708496,
#   2.1565842628479004,
#   2.1988189220428467,
#   2.153552532196045,
#   2.1288180351257324,
#   2.1308915615081787,
#   2.1389265060424805,
#   2.1252331733703613,
#   2.1227097511291504,
#   2.1316657066345215,
#   2.128540515899658,
#   2.130444049835205,
#   2.1219234466552734,
#   2.1153228282928467,
#   2.1024422645568848,
#   2.0993893146514893]}

# %%
pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.ylim(0,50)
# Out:
# (0.0, 50.0)

# %% [markdown]
# ¿Alguna conclusión respecto a este gráfico?

# %% [markdown]
# Earlystopping me ha ayudado a detener el entrenamiento para no caer en overfitting, también para ahorrar recursos innecesarios.

# %% [markdown]
# Observamos que si le damos muchas epochs al entrenamiento tiende a un overfitting, siendo el error en validación cada vez más alto. Sería interesante utilizar un número aprox de 30 epochs

# %% [markdown]
# Añade un early stopping al modelo. Pon el argumento `callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)]` dentro del fit().
#
# Visualiza el progreso de entrenamiento.

# %% [markdown]
# Interpreta el gráfico

# %% [markdown]
# Veamos qué tan bien generaliza el modelo al usar el conjunto de **test**. Esto nos dice qué tan bien podemos esperar que el modelo prediga cuándo lo usamos en el mundo real. Utiliza el método `evaluate` con los datos de test normalizados y sus labels.
#
# Con el método evaluate devolverá tres valores: loss, mae y mse.

# %%
model.evaluate(X_test_scal, y_test)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 8.8201 - mae: 2.1567
# [8.820125579833984, 2.156667709350586]

# %% [markdown]
# Ahora prueba el modelo. Coge 10 ejemplos de test y llama a` model.predict`.

# %%
model.predict(X_test_scal[:10])
# Out:
# 1/1 [==============================] - 0s 169ms/step
# array([[14.593166],
#        [15.229501],
#        [21.443016],
#        [24.103977],
#        [17.155025],
#        [13.074136],
#        [18.863657],
#        [27.082424],
#        [25.001734],
#        [27.18898 ]], dtype=float32)

# %% [markdown]
# ### Haz Predicciones
#
# Dibuja en un scatter plot las predicciones de test vs sus true labels.

# %%
y_pred = model.predict(X_test_scal)
# Out:
# 3/3 [==============================] - 0s 3ms/step

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# Parece que nuestro modelo predice razonablemente bien. Echemos un vistazo a la distribución de errores.
#
# Representa los residuos en un histograma

# %%
error = y_pred.reshape(-1) - y_test
plt.hist(error);

# %% [markdown]
# No es del todo gaussiano, pero podríamos esperar eso porque el número de muestras es muy pequeño.

# %% [markdown]
# Guarda tu modelo en un archivo.

# %%
model.save("final_model.keras")

# %%
imported_model = keras.models.load_model("final_model.keras")
imported_model
