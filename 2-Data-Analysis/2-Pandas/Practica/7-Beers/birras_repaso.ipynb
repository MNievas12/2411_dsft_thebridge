# %% [markdown]
# ![imagen](https://cdn.foodbeast.com/content/wp-content/uploads/2012/03/beer-print-01-selectism.jpg)
#
# # Ejercicio pandas estadística
# Para este ejercicio se ha utilizado [un dataset de un concurso de kaggle](https://www.kaggle.com/nickhould/craft-cans), cuyo reto consiste en predecir el tipo de cerveza en función de sus características (nivel de alcohol, amargura, tamaño...).
#
# # Ejercicio 1
# Importa las librerias que consideres

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Ejercicio 2
# 1. Importa el dataset "datasets_beer.csv"
# 2. Imprime por pantalla los primeros registros.
# 3. ¿Cuáles son sus columnas?
# 4. ¿Qué dimensiones tiene el DataFrame?

# %%
df_beer = pd.read_csv('./data/datasets_beers.csv')
df_beer
# Out:
#       Unnamed: 0    abv   ibu    id                  name  \
# 0              0  0.050   NaN  1436              Pub Beer
# 1              1  0.066   NaN  2265           Devil's Cup
# 2              2  0.071   NaN  2264   Rise of the Phoenix
# 3              3  0.090   NaN  2263              Sinister
# 4              4  0.075   NaN  2262         Sex and Candy
# ...          ...    ...   ...   ...                   ...
# 2405        2405  0.067  45.0   928             Belgorado
# 2406        2406  0.052   NaN   807         Rail Yard Ale
# 2407        2407  0.055   NaN   620       B3K Black Lager
# 2408        2408  0.055  40.0   145   Silverback Pale Ale
# 2409        2409  0.052   NaN    84  Rail Yard Ale (2009)
#
#                                style  brewery_id  ounces
# 0                American Pale Lager         408    12.0
# 1            American Pale Ale (APA)         177    12.0
# 2                       American IPA         177    12.0
# ...

# %%
df_beer.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
df_beer.columns
# Out:
# Index(['Unnamed: 0', 'abv', 'ibu', 'id', 'name', 'style', 'brewery_id',
#        'ounces'],
#       dtype='object')

# %%
df_beer.dtypes
# Out:
# Unnamed: 0      int64
# abv           float64
# ibu           float64
# id              int64
# name           object
# style          object
# brewery_id      int64
# ounces        float64
# dtype: object

# %%
df_beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2410 non-null   int64
#  1   abv         2348 non-null   float64
#  2   ibu         1405 non-null   float64
#  3   id          2410 non-null   int64
#  4   name        2410 non-null   object
#  5   style       2405 non-null   object
#  6   brewery_id  2410 non-null   int64
#  7   ounces      2410 non-null   float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 150.8+ KB

# %%
df_beer.shape
# Out:
# (2410, 8)

# %%
df_beer.describe()
# Out:
#         Unnamed: 0          abv          ibu           id   brewery_id  \
# count  2410.000000  2348.000000  1405.000000  2410.000000  2410.000000
# mean   1204.500000     0.059773    42.713167  1431.113278   231.749793
# std     695.851397     0.013542    25.954066   752.459975   157.685604
# min       0.000000     0.001000     4.000000     1.000000     0.000000
# 25%     602.250000     0.050000    21.000000   808.250000    93.000000
# 50%    1204.500000     0.056000    35.000000  1453.500000   205.000000
# 75%    1806.750000     0.067000    64.000000  2075.750000   366.000000
# max    2409.000000     0.128000   138.000000  2692.000000   557.000000
#
#             ounces
# count  2410.000000
# mean     13.592241
# std       2.352204
# min       8.400000
# 25%      12.000000
# 50%      12.000000
# 75%      16.000000
# max      32.000000

# %% [markdown]
# ## Ejercicio 3
# [Elimina la columna "Unnamed: 0"](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %%
df_beer.drop(columns=['Unnamed: 0'], inplace=True)
df_beer
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
#       brewery_id  ounces
# ...

# %%
# df_beer.to_csv("prueba.csv", index=False)

# %%
df_prueba = pd.read_csv("prueba.csv") # index_col = 0
df_prueba
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
#       brewery_id  ounces
# ...

# %% [markdown]
# ## Ejercicio 4
# ¿Cuántas filas y columnas tiene el dataset?

# %%
df_beer.shape[0]
# Out:
# 2410

# %%
df_beer.shape[1]
# Out:
# 7

# %%
len(df_beer)
# Out:
# 2410

# %%
len(df_beer.index)
# Out:
# 2410

# %%
len(df_beer.columns)
# Out:
# 7

# %% [markdown]
# ## Ejercicio 5
# ¿De qué tipo son los datos?

# %%
df_beer.dtypes
# Out:
# abv           float64
# ibu           float64
# id              int64
# name           object
# style          object
# brewery_id      int64
# ounces        float64
# dtype: object

# %% [markdown]
# ## Ejercicio 6
# Obtén en un nuevo DataFrame un resumen con las principales estadísticas de las columnas numéricas: mean, max, count, cuartiles...

# %%
df_beer[['abv', 'ibu', 'ounces']].describe()
# Out:
#                abv          ibu       ounces
# count  2348.000000  1405.000000  2410.000000
# mean      0.059773    42.713167    13.592241
# std       0.013542    25.954066     2.352204
# min       0.001000     4.000000     8.400000
# 25%       0.050000    21.000000    12.000000
# 50%       0.056000    35.000000    12.000000
# 75%       0.067000    64.000000    16.000000
# max       0.128000   138.000000    32.000000

# %%
df_beer[['abv', 'ibu', 'ounces']].describe().loc[["count","mean"]]
# Out:
#                abv          ibu       ounces
# count  2348.000000  1405.000000  2410.000000
# mean      0.059773    42.713167    13.592241

# %%
df_beer[['abv', 'ibu', 'ounces']].agg(['count', 'mean'])
# Out:
#                abv          ibu       ounces
# count  2348.000000  1405.000000  2410.000000
# mean      0.059773    42.713167    13.592241

# %%
df_beer.aggregate({"abv":["mean", "median"], "ibu": "count"})
# Out:
#              abv     ibu
# mean    0.059773     NaN
# median  0.056000     NaN
# count        NaN  1405.0

# %%
df_beer.describe(include="all")
# Out:
#                 abv          ibu           id             name         style  \
# count   2348.000000  1405.000000  2410.000000             2410          2405
# unique          NaN          NaN          NaN             2305            99
# top             NaN          NaN          NaN  Nonstop Hef Hop  American IPA
# freq            NaN          NaN          NaN               12           424
# mean       0.059773    42.713167  1431.113278              NaN           NaN
# std        0.013542    25.954066   752.459975              NaN           NaN
# min        0.001000     4.000000     1.000000              NaN           NaN
# 25%        0.050000    21.000000   808.250000              NaN           NaN
# 50%        0.056000    35.000000  1453.500000              NaN           NaN
# 75%        0.067000    64.000000  2075.750000              NaN           NaN
# max        0.128000   138.000000  2692.000000              NaN           NaN
#
#          brewery_id       ounces
# ...

# %% [markdown]
# ## Ejercicio 7
# ¿Cuántas birras hay de cada estilo en este dataset? [Investiga en la documentación de Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html) si puedes hacer un conteo de valores.

# %%
df_beer['style'].value_counts()[:10]
# Out:
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
# American Pale Wheat Ale            97
# American Brown Ale                 70
# American Porter                    68
# Saison / Farmhouse Ale             52
# Witbier                            51
# Name: style, dtype: int64

# %%
df_beer['style'].value_counts(normalize=True)[:10]
# Out:
# American IPA                      0.176299
# American Pale Ale (APA)           0.101871
# American Amber / Red Ale          0.055301
# American Blonde Ale               0.044906
# American Double / Imperial IPA    0.043659
# American Pale Wheat Ale           0.040333
# American Brown Ale                0.029106
# American Porter                   0.028274
# Saison / Farmhouse Ale            0.021622
# Witbier                           0.021206
# Name: style, dtype: float64

# %%
df_beer.groupby("style")['id'].count().sort_values(ascending=False)
# Out:
# style
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# Smoked Beer                         1
# Flanders Red Ale                    1
# Kristalweizen                       1
# American Malt Liquor                1
# Flanders Oud Bruin                  1
# Name: id, Length: 99, dtype: int64

# %%
len(df_beer['style'].unique())
# Out:
# 100

# %%
df_beer['style'].nunique()
# Out:
# 99

# %%
df_beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   abv         2348 non-null   float64
#  1   ibu         1405 non-null   float64
#  2   id          2410 non-null   int64
#  3   name        2410 non-null   object
#  4   style       2405 non-null   object
#  5   brewery_id  2410 non-null   int64
#  6   ounces      2410 non-null   float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 131.9+ KB

# %%
df_beer[df_beer['style'].isnull()]
# Out:
#         abv   ibu    id                            name style  brewery_id  \
# 566     NaN   NaN  2210                 Special Release   NaN          29
# 853   0.060  21.0  1635  Kilt Lifter Scottish-Style Ale   NaN         160
# 866   0.053  27.0  2527                   OktoberFiesta   NaN          66
# 1554    NaN   NaN  1796                    The CROWLER™   NaN         166
# 1555    NaN   NaN  1790            CAN'D AID Foundation   NaN         166
#
#       ounces
# 566     16.0
# 853     12.0
# 866     12.0
# 1554    32.0
# 1555    12.0

# %%
df_beer['style'].fillna("Missing style", inplace=True)
df_beer['style'].value_counts()['Missing style']
# Out:
# 5

# %% [markdown]
# ## Ejercicio 8
# 1. Imprime por pantalla los registros desde el décimo hasta el vigésimo
# 2. De esos registros, imprime por pantalla desde la columna `name` a `ounces`, ambas incluidas
# 3. Quédate con las columnas `abv`, `ibu` y `ounces`, y además quédate sólo con los registros 10 al 20.
# 4. Convierte el resultado del apartado 3 en un array de `numpy`

# %%
df_beer.iloc[9:20, :]
# Out:
#       abv   ibu    id                         name  \
# 9   0.086   NaN  2131                 Cone Crusher
# 10  0.072   NaN  2099            Sophomoric Saison
# 11  0.073   NaN  2098        Regional Ring Of Fire
# 12  0.069   NaN  2097                   Garce Selé
# 13  0.085   NaN  1980              Troll Destroyer
# 14  0.061  60.0  1979                 Bitter Bitch
# 15  0.060   NaN  2318                  Ginja Ninja
# 16  0.060   NaN  2170                Cherried Away
# 17  0.060   NaN  2169                 Rhubarbarian
# 18  0.060   NaN  1502                  BrightCider
# 19  0.082   NaN  1593  He Said Baltic-Style Porter
#
#                              style  brewery_id  ounces
# 9   American Double / Imperial IPA         177    12.0
# 10          Saison / Farmhouse Ale         177    12.0
# 11          Saison / Farmhouse Ale         177    12.0
# 12          Saison / Farmhouse Ale         177    12.0
# 13                     Belgian IPA         177    12.0
# ...

# %%
df_beer.iloc[9:20, :].loc[:,"name":"ounces"]
# Out:
#                            name                           style  brewery_id  \
# 9                  Cone Crusher  American Double / Imperial IPA         177
# 10            Sophomoric Saison          Saison / Farmhouse Ale         177
# 11        Regional Ring Of Fire          Saison / Farmhouse Ale         177
# 12                   Garce Selé          Saison / Farmhouse Ale         177
# 13              Troll Destroyer                     Belgian IPA         177
# 14                 Bitter Bitch         American Pale Ale (APA)         177
# 15                  Ginja Ninja                           Cider         154
# 16                Cherried Away                           Cider         154
# 17                 Rhubarbarian                           Cider         154
# 18                  BrightCider                           Cider         154
# 19  He Said Baltic-Style Porter                   Baltic Porter         368
#
#     ounces
# 9     12.0
# 10    12.0
# 11    12.0
# ...

# %%
list(df_beer.columns).index("name")
# Out:
# 3

# %%
df_beer.iloc[9:20, list(df_beer.columns).index("name"):list(df_beer.columns).index("ounces")]
# Out:
#                            name                           style  brewery_id
# 9                  Cone Crusher  American Double / Imperial IPA         177
# 10            Sophomoric Saison          Saison / Farmhouse Ale         177
# 11        Regional Ring Of Fire          Saison / Farmhouse Ale         177
# 12                   Garce Selé          Saison / Farmhouse Ale         177
# 13              Troll Destroyer                     Belgian IPA         177
# 14                 Bitter Bitch         American Pale Ale (APA)         177
# 15                  Ginja Ninja                           Cider         154
# 16                Cherried Away                           Cider         154
# 17                 Rhubarbarian                           Cider         154
# 18                  BrightCider                           Cider         154
# 19  He Said Baltic-Style Porter                   Baltic Porter         368

# %%
list(df_beer.columns)[3:6]
# Out:
# ['name', 'style', 'brewery_id']

# %%
df_beer.iloc[9:20][list(df_beer.columns)[3:6]]
# Out:
#                            name                           style  brewery_id
# 9                  Cone Crusher  American Double / Imperial IPA         177
# 10            Sophomoric Saison          Saison / Farmhouse Ale         177
# 11        Regional Ring Of Fire          Saison / Farmhouse Ale         177
# 12                   Garce Selé          Saison / Farmhouse Ale         177
# 13              Troll Destroyer                     Belgian IPA         177
# 14                 Bitter Bitch         American Pale Ale (APA)         177
# 15                  Ginja Ninja                           Cider         154
# 16                Cherried Away                           Cider         154
# 17                 Rhubarbarian                           Cider         154
# 18                  BrightCider                           Cider         154
# 19  He Said Baltic-Style Porter                   Baltic Porter         368

# %% [markdown]
# ## Ejercicio 9
# ¿Cuántas onzas pesan todas las birras del dataset?

# %%
df_beer['ounces'].sum()
# Out:
# 32757.3

# %%
df_beer[~df_beer['style'].str.contains("Cider")]['ounces'].sum()
# Out:
# 32229.3

# %%
df_beer.groupby("style")['ounces'].sum().sort_values(ascending=False)
# Out:
# style
# American IPA                      5758.4
# American Pale Ale (APA)           3233.6
# American Amber / Red Ale          1768.0
# American Double / Imperial IPA    1487.2
# American Blonde Ale               1424.0
#                                    ...
# Low Alcohol Beer                    16.0
# Braggot                             12.0
# Grisette                            12.0
# Kristalweizen                       12.0
# Other                               12.0
# Name: ounces, Length: 100, dtype: float64

# %% [markdown]
# ## Ejercicio 10
# El amargor de las cervezas se mide por su nivel de IBUs.
# 1. ¿Cuál es el amargor medio de las cervezas?
# 2. ¿El máximo? ¿Y el mínimo?
# 3. ¿Qué cerveza es la que tiene el amargor máximo? ¿Cuál es la de amargor mínimo?

# %%
df_beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   abv         2348 non-null   float64
#  1   ibu         1405 non-null   float64
#  2   id          2410 non-null   int64
#  3   name        2410 non-null   object
#  4   style       2410 non-null   object
#  5   brewery_id  2410 non-null   int64
#  6   ounces      2410 non-null   float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 131.9+ KB

# %%
len(df_beer[df_beer['ibu'].isnull()])/len(df_beer)
# Out:
# 0.4170124481327801

# %%
df_beer['ibu'].mean()
# Out:
# 42.71316725978647

# %%
print(df_beer['ibu'].max())
print(df_beer['ibu'].min())
# Out:
# 138.0
# 4.0

# %%
df_beer[df_beer['ibu'] == df_beer['ibu'].min()]
# Out:
#        abv  ibu    id                                  name      style  \
# 106  0.056  4.0  1350                       Summer Solstice  Cream Ale
# 112  0.056  4.0   753  Summer Solstice Cerveza Crema (2009)  Cream Ale
# 117  0.056  4.0    77                Summer Solstice (2011)  Cream Ale
#
#      brewery_id  ounces
# 106         171    12.0
# 112         171    12.0
# 117         171    12.0

# %%
df_beer[df_beer['ibu'] == df_beer['ibu'].max()]
# Out:
#        abv    ibu   id                       name  \
# 147  0.082  138.0  980  Bitter Bitch Imperial IPA
#
#                               style  brewery_id  ounces
# 147  American Double / Imperial IPA         374    12.0

# %%
df_beer['ibu'].mode()
# Out:
# 0    20.0
# Name: ibu, dtype: float64

# %%
df_beer['ibu'].fillna(df_beer['ibu'].mean())
df_beer['ibu'].fillna(df_beer['ibu'].median())
df_beer['ibu'].fillna(df_beer['ibu'].mode()[0])
# Out:
# 0       20.0
# 1       20.0
# 2       20.0
# 3       20.0
# 4       20.0
#         ...
# 2405    45.0
# 2406    20.0
# 2407    20.0
# 2408    40.0
# 2409    20.0
# Name: ibu, Length: 2410, dtype: float64

# %%
df_beer['ibu'].std()
# Out:
# 25.954065911259317

# %%
median_ibu_style = df_beer.groupby("style")[['ibu']].median()
median_ibu_style
# Out:
#                              ibu
# style
# Abbey Single Ale            22.0
# Altbier                     36.5
# American Adjunct Lager       9.0
# American Amber / Red Ale    31.0
# American Amber / Red Lager  23.0
# ...                          ...
# Tripel                      27.5
# Vienna Lager                23.5
# Wheat Ale                   24.0
# Winter Warmer               22.0
# Witbier                     15.5
#
# [100 rows x 1 columns]

# %%
median_ibu_style[median_ibu_style['ibu'].isnull()]
# Out:
#                       ibu
# style
# American Malt Liquor  NaN
# Braggot               NaN
# Cider                 NaN
# Flanders Red Ale      NaN
# Kristalweizen         NaN
# Low Alcohol Beer      NaN
# Mead                  NaN
# Rauchbier             NaN
# Shandy                NaN

# %%
df_beer = df_beer.merge(median_ibu_style, left_on="style", right_index=True, how="left")
df_beer
# Out:
#         abv  ibu_x    id                  name  \
# 0     0.050    NaN  1436              Pub Beer
# 1     0.066    NaN  2265           Devil's Cup
# 2     0.071    NaN  2264   Rise of the Phoenix
# 3     0.090    NaN  2263              Sinister
# 4     0.075    NaN  2262         Sex and Candy
# ...     ...    ...   ...                   ...
# 2405  0.067   45.0   928             Belgorado
# 2406  0.052    NaN   807         Rail Yard Ale
# 2407  0.055    NaN   620       B3K Black Lager
# 2408  0.055   40.0   145   Silverback Pale Ale
# 2409  0.052    NaN    84  Rail Yard Ale (2009)
#
#                                style  brewery_id  ounces  ibu_y
# 0                American Pale Lager         408    12.0   18.5
# 1            American Pale Ale (APA)         177    12.0   44.0
# 2                       American IPA         177    12.0   69.0
# 3     American Double / Imperial IPA         177    12.0   91.0
# 4                       American IPA         177    12.0   69.0
# ...

# %%
df_beer['ibu_imp'] = np.where(df_beer['ibu_x'].isnull(), df_beer['ibu_y'], df_beer['ibu_x'])
df_beer
# Out:
#         abv  ibu_x    id                  name  \
# 0     0.050    NaN  1436              Pub Beer
# 1     0.066    NaN  2265           Devil's Cup
# 2     0.071    NaN  2264   Rise of the Phoenix
# 3     0.090    NaN  2263              Sinister
# 4     0.075    NaN  2262         Sex and Candy
# ...     ...    ...   ...                   ...
# 2405  0.067   45.0   928             Belgorado
# 2406  0.052    NaN   807         Rail Yard Ale
# 2407  0.055    NaN   620       B3K Black Lager
# 2408  0.055   40.0   145   Silverback Pale Ale
# 2409  0.052    NaN    84  Rail Yard Ale (2009)
#
#                                style  brewery_id  ounces  ibu_y  ibu_imp
# 0                American Pale Lager         408    12.0   18.5     18.5
# 1            American Pale Ale (APA)         177    12.0   44.0     44.0
# 2                       American IPA         177    12.0   69.0     69.0
# 3     American Double / Imperial IPA         177    12.0   91.0     91.0
# ...

# %%
df_beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   abv         2348 non-null   float64
#  1   ibu_x       1405 non-null   float64
#  2   id          2410 non-null   int64
#  3   name        2410 non-null   object
#  4   style       2410 non-null   object
#  5   brewery_id  2410 non-null   int64
#  6   ounces      2410 non-null   float64
#  7   ibu_y       2358 non-null   float64
#  8   ibu_imp     2358 non-null   float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 169.6+ KB

# %%
df_beer['ibu_imp'].fillna(df_beer['ibu_imp'].median(), inplace=True)
df_beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   abv         2348 non-null   float64
#  1   ibu_x       1405 non-null   float64
#  2   id          2410 non-null   int64
#  3   name        2410 non-null   object
#  4   style       2410 non-null   object
#  5   brewery_id  2410 non-null   int64
#  6   ounces      2410 non-null   float64
#  7   ibu_y       2358 non-null   float64
#  8   ibu_imp     2410 non-null   float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 169.6+ KB

# %%
df_beer['ibu_x'].mean()
# Out:
# 42.71316725978647

# %%
df_beer['ibu_imp'].mean()
# Out:
# 40.31369294605809

# %% [markdown]
# ## Ejercicio 11
# No queda muy claro cuánto de dispar, de dispersa, es la medida de IBU. Mediante estadística descriptiva (una o dos métricas, sin gráficas), razona la dispersión de la variable IBU.

# %%
df_beer.rename(columns={'ibu_x':'ibu'}, inplace=True)
df_beer
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
# ...

# %%
df_beer['ibu'].std()
# Out:
# 25.954065911259317

# %%
df_beer['ibu'].std() **2
# Out:
# 673.6135373259929

# %%
df_beer['ibu'].var()
# Out:
# 673.6135373259929

# %%
df_beer['ibu'].max() - df_beer['ibu'].min()
# Out:
# 134.0

# %%
np.percentile(df_beer['ibu_imp'], 90) - np.percentile(df_beer['ibu_imp'], 10)
# Out:
# 57.0

# %% [markdown]
# ## Ejercicio 12
# ¿Existe alguna relación lineal entre las variables numéricas del dataset? Intenta pintar este razonamiento mediante un gráfico

# %%
df_beer[['abv','ibu','ounces']].corr()
# Out:
#              abv       ibu    ounces
# abv     1.000000  0.670621  0.172529
# ibu     0.670621  1.000000  0.054691
# ounces  0.172529  0.054691  1.000000

# %%
import seaborn as sns

sns.heatmap(df_beer[['abv','ibu','ounces']].corr(), annot=True, cmap="coolwarm", vmin=-1)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

plt.scatter(df_beer['abv'], df_beer['ibu'])

# %% [markdown]
# ## Ejercicio 13
# Representa el nivel de alcohol (columna `abv`) en un histograma. ¿Se trata de una distribución simétrica o asimétrica?

# %%
df_beer['abv'].hist(bins=50)
# Out:
# <Axes: >

# %%
df_beer['abv'].skew()
# Out:
# 0.9584771340361382

# %% [markdown]
# ## Ejercicio 14
# Representa mediante un *boxplot* de `seaborn` la variable `abv`

# %%
sns.boxplot(x=df_beer['abv'])
# Out:
# <Axes: xlabel='abv'>

# %% [markdown]
# ## Ejercicio 15
# 1. ¿Qué estilos son los que tienen en media más alcohol?
# 2. ¿Y los estilos que son en media más amargos?

# %%
df_beer.groupby("style")['abv'].mean().sort_values(ascending=False)
# Out:
# style
# English Barleywine        0.107667
# Quadrupel (Quad)          0.104000
# American Barleywine       0.099000
# American Malt Liquor      0.099000
# Russian Imperial Stout    0.097636
#                             ...
# Berliner Weissbier        0.043909
# English Dark Mild Ale     0.041500
# Light Lager               0.040417
# Radler                    0.040333
# Low Alcohol Beer          0.001000
# Name: abv, Length: 100, dtype: float64

# %%
df_beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   abv         2348 non-null   float64
#  1   ibu         1405 non-null   float64
#  2   id          2410 non-null   int64
#  3   name        2410 non-null   object
#  4   style       2410 non-null   object
#  5   brewery_id  2410 non-null   int64
#  6   ounces      2410 non-null   float64
#  7   ibu_y       2358 non-null   float64
#  8   ibu_imp     2410 non-null   float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 169.6+ KB

# %%
df_beer.groupby("style")['abv'].agg(["mean", "count"]).sort_values("mean", ascending=False)
# Out:
#                             mean  count
# style
# English Barleywine      0.107667      3
# Quadrupel (Quad)        0.104000      4
# American Barleywine     0.099000      3
# American Malt Liquor    0.099000      1
# Russian Imperial Stout  0.097636     11
# ...                          ...    ...
# Berliner Weissbier      0.043909     11
# English Dark Mild Ale   0.041500      4
# Light Lager             0.040417     12
# Radler                  0.040333      3
# Low Alcohol Beer        0.001000      1
#
# [100 rows x 2 columns]

# %%
df_beer.groupby("style")['ibu_imp'].agg(["mean", "count"]).sort_values("mean", ascending=False)
# Out:
#                                          mean  count
# style
# American Barleywine                 96.000000      3
# American Double / Imperial IPA      92.657143    105
# Russian Imperial Stout              88.545455     11
# American Double / Imperial Pilsner  85.000000      2
# Belgian Strong Dark Ale             72.000000      6
# ...                                       ...    ...
# Fruit / Vegetable Beer              14.704082     49
# Light Lager                         11.916667     12
# American Adjunct Lager              10.222222     18
# Gose                                 9.600000     10
# Berliner Weissbier                   7.909091     11
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Ejercicio 16
# Carga el datasets de cervecerias `datasets_breweries.csv`

# %%
df_brew = pd.read_csv("./data/datasets_breweries.csv")
df_brew
# Out:
#      Unnamed: 0                           name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %%
df_brew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558 entries, 0 to 557
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  558 non-null    int64
#  1   name        558 non-null    object
#  2   city        558 non-null    object
#  3   state       558 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 17.6+ KB

# %% [markdown]
# ## Ejercicio 17
# 1. Renombra la columna `Unnamed: 0` como `brewery_id`
# 2. Renombra también la columna `name` por `brewery_name`. ¿Puedes hacer ambos apartados en una sola sentencia?

# %%
df_brew.rename(columns={"Unnamed: 0": "brewery_id", "name":"brewery_name"}, inplace=True)
df_brew
# Out:
#      brewery_id                   brewery_name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 18
# Junta los dos datasets que tienes

# %%
df_beer.drop(columns=['ibu_y'], inplace=True)
df_beer.head()
# Out:
#      abv  ibu    id                 name                           style  \
# 0  0.050  NaN  1436             Pub Beer             American Pale Lager
# 1  0.066  NaN  2265          Devil's Cup         American Pale Ale (APA)
# 2  0.071  NaN  2264  Rise of the Phoenix                    American IPA
# 3  0.090  NaN  2263             Sinister  American Double / Imperial IPA
# 4  0.075  NaN  2262        Sex and Candy                    American IPA
#
#    brewery_id  ounces  ibu_imp
# 0         408    12.0     18.5
# 1         177    12.0     44.0
# 2         177    12.0     69.0
# 3         177    12.0     91.0
# 4         177    12.0     69.0

# %%
df_brew.head()
# Out:
#    brewery_id               brewery_name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %%
df_all = pd.merge(df_beer, df_brew, on="brewery_id", how="outer")
df_all
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
# ...

# %% [markdown]
# ## Ejercicio 19
# 1. ¿Cuántos estados diferentes hay?
# 2. ¿Y ciudades diferentes?
# 3. ¿Cuántas cervecerías hay?

# %%
df_all['state'].nunique()
# Out:
# 51

# %%
df_all['city'].nunique()
# Out:
# 384

# %%
df_all['brewery_name'].nunique()
# Out:
# 551

# %%
df_all['brewery_id'].nunique()
# Out:
# 558

# %%
cervecerias = df_all.groupby("brewery_name")['brewery_id'].nunique().sort_values(ascending=False)
cervecerias[cervecerias > 1].index
# Out:
# Index(['Blackrocks Brewery', 'Sly Fox Brewing Company',
#        'Summit Brewing Company', 'Oskar Blues Brewery', 'Otter Creek Brewing',
#        'Lucette Brewing Company', 'Blue Mountain Brewery'],
#       dtype='object', name='brewery_name')

# %% [markdown]
# ## Ejercicio 20
# Agrupa por estado y ciudad, la media, mediana y máximo nivel de alcohol

# %%
df_all.groupby(['state','city'])['abv'].agg(['mean','median','max', 'count'])
# Out:
#                       mean  median    max  count
# state city
#  AK   Anchorage   0.054200  0.0520  0.063     15
#       Juneau      0.053000  0.0530  0.053      2
#       Soldotna    0.058500  0.0580  0.068      4
#       Talkeetna   0.059500  0.0585  0.065      4
#  AL   Birmingham  0.065400  0.0600  0.093      5
# ...                    ...     ...    ...    ...
#  WI   Wilson      0.055000  0.0550  0.055      1
#  WV   Lewisburg   0.062000  0.0620  0.067      2
#  WY   Jackson     0.054857  0.0520  0.068      7
#       Pinedale    0.061000  0.0610  0.072      2
#       Sheridan    0.052833  0.0480  0.070      6
#
# [401 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 21
# ¿Cuáles son las cervezas más amargas que se consumen en Indiana, estado = `IN`?

# %%
df_all[df_all['state'] == "IN"]
# Out:
# Empty DataFrame
# Columns: [abv, ibu, id, name, style, brewery_id, ounces, ibu_imp, brewery_name, city, state]
# Index: []

# %%
df_all.head()
# Out:
#      abv  ibu    id                 name                           style  \
# 0  0.050  NaN  1436             Pub Beer             American Pale Lager
# 1  0.066  NaN  2265          Devil's Cup         American Pale Ale (APA)
# 2  0.071  NaN  2264  Rise of the Phoenix                    American IPA
# 3  0.090  NaN  2263             Sinister  American Double / Imperial IPA
# 4  0.075  NaN  2262        Sex and Candy                    American IPA
#
#    brewery_id  ounces  ibu_imp               brewery_name  city state
# 0         408    12.0     18.5  10 Barrel Brewing Company  Bend    OR
# 1         177    12.0     44.0        18th Street Brewery  Gary    IN
# 2         177    12.0     69.0        18th Street Brewery  Gary    IN
# 3         177    12.0     91.0        18th Street Brewery  Gary    IN
# 4         177    12.0     69.0        18th Street Brewery  Gary    IN

# %%
df_all['state'].unique()
# Out:
# array([' OR', ' IN', ' CA', ' FL', ' MO', ' WA', ' CO', ' LA', ' KY',
#        ' AK', ' WI', ' OH', ' OK', ' NC', ' MI', ' TX', ' CT', ' AL',
#        ' MA', ' AZ', ' MN', ' ME', ' VA', ' IL', ' TN', ' MT', ' WY',
#        ' NE', ' NY', ' UT', ' NJ', ' PA', ' NV', ' SC', ' GA', ' RI',
#        ' IA', ' AR', ' ID', ' SD', ' DC', ' KS', ' ND', ' VT', ' MD',
#        ' WV', ' HI', ' DE', ' NM', ' MS', ' NH'], dtype=object)

# %%
df_all.loc[1, "state"]
# Out:
# ' IN'

# %%
df_all[df_all['state'].str.contains("IN")].sort_values("ibu", ascending=False)
# Out:
#         abv    ibu    id                          name  \
# 479   0.099  115.0  2471              Hopkick Dropkick
# 2191  0.085  115.0  1449         Overlord Imperial IPA
# 811   0.060  104.0  1610                Half Cycle IPA
# 2062  0.091   91.0   651                          Isis
# 2189  0.120   90.0  2621                          Csar
# ...     ...    ...   ...                           ...
# 2056  0.070    NaN   934                     The Deuce
# 2061  0.080    NaN   660                         Chaka
# 2190  0.055    NaN  1817  Klingon Warnog Roggen Dunkel
# 2277  0.060    NaN  1950                 Dragonfly IPA
# 2329  0.047    NaN   780            T-6 Red Ale (2004)
#
#                                style  brewery_id  ounces  ibu_imp  \
# 479   American Double / Imperial IPA          24    12.0    115.0
# 2191  American Double / Imperial IPA          17    16.0    115.0
# 811                     American IPA          16    16.0    104.0
# ...

# %%
df_all['state'] = df_all['state'].str.replace(" ", "")
df_all[df_all['state'] == "IN"]
# Out:
#         abv   ibu    id                      name  \
# 1     0.066   NaN  2265               Devil's Cup
# 2     0.071   NaN  2264       Rise of the Phoenix
# 3     0.090   NaN  2263                  Sinister
# 4     0.075   NaN  2262             Sex and Candy
# 5     0.077   NaN  2261              Black Exodus
# ...     ...   ...   ...                       ...
# 2195  0.045  35.0   948  Circuit Bohemian Pilsner
# 2275  0.045  50.0  2190      Campside Session IPA
# 2276  0.045  15.0  1951          Upland Wheat Ale
# 2277  0.060   NaN  1950             Dragonfly IPA
# 2329  0.047   NaN   780        T-6 Red Ale (2004)
#
#                                style  brewery_id  ounces  ibu_imp  \
# 1            American Pale Ale (APA)         177    12.0     44.0
# 2                       American IPA         177    12.0     69.0
# 3     American Double / Imperial IPA         177    12.0     91.0
# 4                       American IPA         177    12.0     69.0
# ...

# %% [markdown]
# ## Ejercicio 22
# Obtén una tabla con los principales estadísticos del campo `ibu`,  a nivel ciudad

# %%
df_all['ibu'].describe()
# Out:
# count    1405.000000
# mean       42.713167
# std        25.954066
# min         4.000000
# 25%        21.000000
# 50%        35.000000
# 75%        64.000000
# max       138.000000
# Name: ibu, dtype: float64

# %%
df_all.groupby("city")[['ibu']].describe()
# Out:
#                  ibu                                                       \
#                count        mean        std    min     25%    50%     75%
# city
# Abingdon         1.0  135.000000        NaN  135.0  135.00  135.0  135.00
# Abita Springs    3.0   27.333333  21.455380   13.0   15.00   17.0   34.50
# Ada              0.0         NaN        NaN    NaN     NaN    NaN     NaN
# Afton            4.0   43.000000  19.899749   22.0   28.00   45.0   60.00
# Airway Heights   0.0         NaN        NaN    NaN     NaN    NaN     NaN
# ...              ...         ...        ...    ...     ...    ...     ...
# Woodinville      4.0   46.750000  18.643587   27.0   39.75   44.0   51.00
# Worcester        1.0   69.000000        NaN   69.0   69.00   69.0   69.00
# Yakima           2.0   54.000000  22.627417   38.0   46.00   54.0   62.00
# Yardley          0.0         NaN        NaN    NaN     NaN    NaN     NaN
# York             4.0   44.250000  22.779742   20.0   35.00   41.0   50.25
#
# ...

# %%
df_all.groupby("city")[['ibu_imp']].describe()
# Out:
#                ibu_imp                                                       \
#                  count        mean        std    min     25%    50%     75%
# city
# Abingdon           1.0  135.000000        NaN  135.0  135.00  135.0  135.00
# Abita Springs      3.0   27.333333  21.455380   13.0   15.00   17.0   34.50
# Ada                1.0   32.000000        NaN   32.0   32.00   32.0   32.00
# Afton              4.0   43.000000  19.899749   22.0   28.00   45.0   60.00
# Airway Heights     5.0   18.800000   4.309872   12.0   18.50   18.5   22.00
# ...                ...         ...        ...    ...     ...    ...     ...
# Woodinville        4.0   46.750000  18.643587   27.0   39.75   44.0   51.00
# Worcester          1.0   69.000000        NaN   69.0   69.00   69.0   69.00
# Yakima             2.0   54.000000  22.627417   38.0   46.00   54.0   62.00
# Yardley            1.0   40.000000        NaN   40.0   40.00   40.0   40.00
# ...

# %%
df_all.groupby("city")[['ibu_imp']].agg(pd.Series.mode)
# Out:
#                                  ibu_imp
# city
# Abingdon                           135.0
# Abita Springs         [13.0, 17.0, 52.0]
# Ada                                 32.0
# Afton                               60.0
# Airway Heights                      18.5
# ...                                  ...
# Woodinville                         44.0
# Worcester                           69.0
# Yakima                      [38.0, 70.0]
# Yardley                             40.0
# York            [20.0, 40.0, 42.0, 75.0]
#
# [384 rows x 1 columns]

# %% [markdown]
# ## Ejercicio 23
# Consigue en un DataFrame todas las cervezas en cuyas cervecerías al menos haya una cerveza con un `abv` mínimo 0.07.

# %%
# Listado de cervezzas
# Pertenezcan a una serie de cervecerías
# En esa cervecería, tiene que haber al menos una, que tenga 0.07 o más

# %%
# df_all.groupby('brewery_id')['abv'].min()
# Out:
# brewery_id
# 0      0.045
# 1      0.040
# 2      0.048
# 3      0.058
# 4      0.046
#        ...
# 553    0.050
# 554    0.055
# 555    0.055
# 556    0.043
# 557    0.049
# Name: abv, Length: 558, dtype: float64

# %%
cervecerias = df_all[df_all['abv'] >= 0.07]['brewery_id'].unique()
cervecerias
# Out:
# array([177, 368,  67,  27, 481,  62,   1, 117, 171, 193,  69, 426, 429,
#        353, 523, 374,  72, 413,  37, 360, 235,  34,  20, 292, 306,  76,
#         53,  75, 463, 220, 477,   8,  40, 336, 444,  18, 112, 294,  95,
#         12, 380, 304, 489, 107, 231, 219, 308,  10, 530, 214,  24,   5,
#        230, 222, 331, 285,  29, 350, 236, 226,  99, 141, 515,  63, 315,
#        227, 358, 127, 263,  57, 491, 369, 465,  26, 173, 224, 405, 201,
#        172, 256,  48, 521,  50, 279, 206,  15, 287, 105, 460, 433, 180,
#        228, 240,  39, 464, 478, 165,   6, 365,  86, 124, 327, 248, 343,
#        204, 280, 479, 423, 168, 198, 395,  80, 242,   2,  92, 233, 208,
#        125, 354, 332, 149, 268,  91, 356, 346, 317, 161, 375, 203, 393,
#          3,  65, 284, 134,  98, 209, 514, 188, 260, 507, 143, 387, 410,
#        174, 495, 359, 184, 148, 471, 301, 166, 503, 389, 355, 314, 274,
#        128, 475,  68, 421, 110,  93,  43, 229, 376, 164, 397,  30, 252,
# ...

# %%
df_all[df_all['brewery_id'].isin(cervecerias)]
# Out:
#         abv   ibu    id                  name                           style  \
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# 5     0.077   NaN  2261          Black Exodus                   Oatmeal Stout
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
# ...

# %%
cervecerias = df_all.groupby('brewery_id')['abv'].max()
cervecerias = cervecerias[cervecerias >= 0.07].index
df_all[df_all['brewery_id'].isin(cervecerias)]
# Out:
#         abv   ibu    id                  name                           style  \
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# 5     0.077   NaN  2261          Black Exodus                   Oatmeal Stout
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
# ...

# %% [markdown]
# ## Ejercicio 24
# Teniendo en cuenta la media de amargor de todas las cervezas, obtén una tabla con las cervezas cuyos estados tengan una media de amargor en cerveza por encima de la media

# %%
# Listado de cervezas
# Filtro por estado
# La media de las cervezas del estado, tiene que estar por encima de la media general

# %%
df_all['ibu'].mean()
# Out:
# 42.71316725978647

# %%
estados_amargor = df_all.groupby("state")['ibu'].mean()
estados_amargor
# Out:
# state
# AK    40.882353
# AL    51.222222
# AR    39.000000
# AZ    35.208333
# CA    46.281481
# CO    47.431507
# CT    40.833333
# DC    55.250000
# DE    52.000000
# FL    46.756757
# GA    46.285714
# HI    32.666667
# IA    33.200000
# ID    55.117647
# IL    41.461538
# IN    42.989011
# KS    36.684211
# KY    40.714286
# LA    33.000000
# MA    38.000000
# MD    36.800000
# ME    52.857143
# MI    36.736842
# MN    49.956522
# MO    32.482759
# MS    46.454545
# MT    41.695652
# NC    43.300000
# ND    40.333333
# NE    30.666667
# NH    48.500000
# NJ    46.375000
# NM    57.000000
# NV    46.500000
# NY    46.000000
# OH    44.187500
# OK    40.727273
# OR    47.942529
# PA    42.446809
# RI    31.550000
# SC    30.200000
# SD          NaN
# TN    41.600000
# TX    40.393258
# UT    45.545455
# VA    45.371429
# VT    42.294118
# WA    44.976744
# WI    26.547619
# WV    57.500000
# WY    32.083333
# Name: ibu, dtype: float64

# %%
estados_filtro = estados_amargor[estados_amargor > df_all['ibu'].mean()].index
estados_filtro
# Out:
# Index(['AL', 'CA', 'CO', 'DC', 'DE', 'FL', 'GA', 'ID', 'IN', 'ME', 'MN', 'MS',
#        'NC', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OR', 'UT', 'VA', 'WA', 'WV'],
#       dtype='object', name='state')

# %%
df_all[df_all['state'].isin(estados_filtro)]
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
# ...
